# %%
# Question 1  (a)

# %%
import numpy as np
data = np.genfromtxt('linear.csv',delimiter=',')
X = data[:,1:]
Y = data[:,0]
# print(Y)
vX = data[:10, 1:]
vY = data[:10, 0]

tX = data[10:, 1:]
tY = data[10:, 0]
print(vX.shape, vY.shape, tX.shape, tY.shape)
# Out:
# (10, 4) (10,) (40, 4) (40,)

# %%
# Question 1  (b)

# %%
import theano
import theano.tensor as T
d = X.shape[1]     # dimension of feature vectors
n = X.shape[0]     # number of training samples
learn_rate = 0.5     # learning rate for gradient descent
lamda = 0.15

# %%
x = T.matrix(name='x')     # feature matrix
y = T.vector(name='y')     # responese vector
w = theano.shared(np.zeros((d,1)),name='w')     # model parameteres

# %%
risk = T.sum((T.dot(x,w).T - y)**2)/2/n + T.sum(w**2) * lamda / 2     # empirical risk
grad_risk = T.grad(risk, wrt=w)     # gradient of the risk

# print(grad_risk)

# %%
train_model = theano.function(inputs=[],
                             outputs=risk,
                             updates=[(w, w-learn_rate*grad_risk)],
                             givens={x:tX, y:tY})

# %%
n_steps = 50
lost_list = []
w_dict = {}
for i in range(n_steps):
#     print(train_model())
#     print(w.get_value())
    lost_list.append(train_model().item(0))
    w_dict[lost_list[-1]] = w.get_value()
    
lost_list.sort()
print(w_dict[lost_list[0]])
# print(lost_list)
# Out:
# [[-0.57709312]
#  [ 1.10605842]
#  [ 0.05230301]
#  [-1.54104119]]

# %%
# Question 1  (c)

# %%
from scipy.optimize import fmin_l_bfgs_b as minimize
def costgrad(w,x,y):
    cost = np.sum((np.matmul(x,w) -y)**2)/2/n + np.sum(w**2) *lamda / 2
    grad = lamda *w + np.matmul(np.matmul(x.transpose(), x), w) / n - np.matmul(x.transpose(), y) / n
    return cost, grad

ww = np.random.randn(d)
optx, cost, messages = minimize(costgrad, ww, args=[tX, tY])
print(optx, cost, messages)
# Out:
# [-0.57708893  1.10606186  0.05231525 -1.54104659] 0.3600336086922588 {'grad': array([ 2.38655728e-06,  2.62212036e-06,  9.29299785e-06, -4.15807816e-06]), 'task': b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL', 'funcalls': 7, 'nit': 6, 'warnflag': 0}

# %%
# Question 1  (d)

# %%
def ridge_regression(tX, tY, l):
    features = tX.shape[1]
    identical = features * l *np.identity(features)
    befinv = identical + np.matmul(tX.transpose(), tX)
    aftinv = np.linalg.inv(befinv)
    fst = np.matmul(aftinv, tX.transpose())
    return np.matmul(fst, tY)
ridge_regression(tX, tY, 0.15)
# Out:
# array([-0.57293812,  1.34849   ,  0.03132541, -1.85105483])

# %%
# Question 1  (e)

# %%
# %matplotlib notebook
tn = tX.shape[0]
vn = vX.shape[0]
tloss = []
vloss = []
vdic = {}
index = -np.arange(0,5,0.1)
for i in index:
    w = ridge_regression(tX, tY, 10**i)
    tloss = tloss+[np.sum((np.dot(tX,w)-tY)**2)/tn/2]
    vsingle = np.sum((np.dot(vX,w)-vY)**2)/vn/2
    vloss = vloss+[vsingle]
    vdic[vsingle] = i
import matplotlib.pyplot as plt
plt.plot(index, np.log(tloss), 'r')
plt.plot(index, np.log(vloss), 'b')
vloss.sort()
llan = vdic[vloss[0]]
print(10**llan)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.12589254117941673
